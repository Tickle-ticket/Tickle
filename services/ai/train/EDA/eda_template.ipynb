# %% [markdown]
# # 휴먼 vs 매크로 행동 데이터 EDA

# %% [markdown]
# ## 1. 데이터 로드

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ## 3. 기본 분석

# %% [markdown]
# ### 3-1 데이터 분포 시각화

# %% [markdown]
# ### 3-2 상관관계 분석

# %% [markdown]
# ### 3-3 PCA

# %% [markdown]
# ## 4. Personal EDA

# %% [markdown]
# ## 5. 분석 리포트
