# %% [markdown]
# # 입력 feature 선택 및 OO모델 학습 및 검증

# %% [markdown]
# ## 1. 데이터 준비

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ## 3. 모델 준비

# %% [markdown]
# ## 4. 모델 학습

# %% [markdown]
# ## 5. 모델 검증

# %% [markdown]
# ## 6. 모델 저장

# %% [markdown]
# ## 7. 결과 리포트
